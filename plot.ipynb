# %%
from utils import plot_result

vit_homemade_name_list = ['vit_D1_E512_H1_R224_P16', 'vit_D1_E512_H4_R224_P16','vit_D4_E512_H1_R224_P16', 'vit_D4_E512_H4_R224_P16', 
                          'vit_D8_E512_H1_R224_P16', 'vit_D8_E512_H4_R224_P16','vit_D8_E512_H4_R224_P32', 'vit_D12_E512_H8_R224_P32']

covit_name_list = ['covit_D1_E512_K3_R224_P16','covit_D1_E512_K3333_R224_P16','covit_D4_E512_K3_R224_P16','covit_D4_E512_K3333_R224_P16',
                   'covit_D4_E512_K7777_R224_P16', 'covit_D8_E512_K3_R224_P16', 'covit_D8_E512_K1357_R224_P16', 'covit_D8_E512_K3333_R224_P16',
                   'covit_D8_E512_K3333_R224_P32','covit_D8_E512_K7777_R224_P16','covit_D12_E512_4xK3_4xK5_R224_P32','covit_D16_E512_4xK3_4xK5_R224_P32'
                  ]
for name in covit_name_list:
    plot_result(name,f'./log_zoo/training_results_{name}.csv', f'./plots/training_results_{name}.png')
